# %%
import pandas as pd
import numpy as np
import os

# %%
df = pd.read_pickle('/Users/user/Documents/Instacart Basket Analysis/02 Data/Prepared Data/final_merge_2.pkl')

# %%
pd.options.display.max_columns= None

# %%
df.head()
# Out:
#    product_id                product_name  aisle_id  department_id  prices  \
# 0           1  Chocolate Sandwich Cookies        61             19     5.8
# 1           1  Chocolate Sandwich Cookies        61             19     5.8
# 2         907        Premium Sliced Bacon       106             12    20.0
# 3         907        Premium Sliced Bacon       106             12    20.0
# 4        1000                    Apricots        18             10    12.9
#
#    order_id  user_id  order_number  orders_days_of_week  order_hour_of_day  \
# 0   3139998      138            28                    6                 11
# 1   1977647      138            30                    6                 17
# 2   3160996      138             1                    5                 13
# 3   2254091      138            10                    5                 14
# 4    505689      138             9                    6                 12
#
# ...

# %%
crosstab = pd.crosstab(df['days_since_prior_order'], df['order_number'], dropna=False)

# %%
crosstab.to_clipboard()

# %%
# Assuming 'df' is your DataFrame
column_names_df = pd.DataFrame(df.columns).T
column_names_df.to_clipboard()

# %%
# Copy column names to clipboard, ready to paste in Excel
df.columns.to_series().to_clipboard(index=False, header=False)
